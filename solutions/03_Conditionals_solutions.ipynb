# %% [markdown]
# # Conditionals
#
# In this notebook, we'll encounter another type of variable, a **Boolean**. We'll talk about the ways that we can use comparisons and boolean operators to write conditional statements.
#
# ### At the end of this notebook, you'll be able to:
#
# * [Recognize and use different types of operators (Boolean and comparison)](#operators)
# * [Write and test conditional statements in Python](#conditionals)
#
# <hr>
#
# <a id="Operators"></a>
#
# ## Comparison and Boolean Operators
#
# We can use *comparison operators* to test the relationship between two objects. These statements return **Booleans**, dictating the flow of our programs through logic gates.
#
# **Booleans** (class type `bool`) are variables that store `True` or `False`. They are named after the British mathematician George Boole (1815–1864). He first formulated Boolean algebra, which are a set of rules for how to reason with and combine these values. This is the basis of all modern computer logic!
#
# **Note:** Capitalization *still* matters! 'TRUE' and 'true' are not Booleans. 'FALSE' and 'false' are not Booleans.

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(type(False))
# Out:
# <class 'bool'>

# %%
type(FALSE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f80fe4603aff> in <module>
# ----> 1 type(FALSE)
#
# NameError: name 'FALSE' is not defined

# %%
type(true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6f4d8242c3d0> in <module>
# ----> 1 type(true)
#
# NameError: name 'true' is not defined

# %% [markdown]
# ### Comparison Operators:
#
# More often than not, your boolean variables will be a result of statements containing comparison operators.
#
# | Symbol |    Operation   | Usage | Boolean Outcome |
# |:------:|:--------------:|:-----:|:-------:|
# |    ==   |  is equal to  |`10==5*2`| True |
# |    !=   | is not equal to | `10!=5*2` | False |
# |    >  | Greater than |  `10 > 2` | True |
# |    <   |    Less than    |  `10 < 2` | False |
# | >= | Greater than _or_ equal to | `10 >= 10` | True |
# | <= | Less than _or_ equal to | `10 <= 10` | True |
#
# #### Other operators:
#
# | "Symbol" |    Operation   | Usage | Boolean Outcome |
# |:------:|:--------------:|:-----:|:-------:|
# | `is` | identity | 10 is 10 | True |
# | `in` | membership | 10 in [1, 2, 3] | False |
#
# But you'll see `is` and `in` described in later notebooks.
#
# <div class="alert alert-success"><b>Task:</b> Test six of the comparison operators ( <code>==</code>, <code>!=</code>, <code>></code>, <code><</code>, <code>>=</code>, <code><=</code>), saving their Boolean outputs to a variable.</div>

# %%
# Test the comparison operators here!

# is equal to
var = (4 * 10) == (5 * 9)
print(var)

# is not equal to
var_2 = 4 != 5
print(var_2)

# greater than
var_3 = 4 > 5
print(var_3)

# less than
var_4 = 4 < 5
print(var_4)

# greater than or equal to
var_5 = 4 >= 5
print(var_5)

# less than or equal to
var_6 = 4 <= 5
print(var_6)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ### Boolean Operators:
#
# Boolean *operators* use Boolean logic. Boolean operators include:
# - `and` : returns `True` only if both statements are `True`
# - `or` : returns `True` if at least one statement is `True`
# - `not` : returns `True` only if the satement is `False`

# %% [markdown]
# *Made in Adobe Illustrator:*

# %% [markdown]
# ![AND_FlowChart.png](data:image/png;base64,...)

# %% [markdown]
# ![OR_FlowChart.png](data:image/png;base64,...)

# %% [markdown]
# ![NOT_FlowChart.png](data:image/png;base64,...)

# %% [markdown]
# <div class="alert alert-success"><b>Task:</b> For each Boolean operator, create a statement that returns True using any of the comparison operators. </div>

# %%
# Example variables to use:
var_1 = 5
var_2 = 50/var_1

var_3 = 24.6
var_4 = 5.0

# %%
# Write your code below here, filling in the parantheses with comparisons:

true_statement_1 = (var_1 < var_3) and (var_3 > var_5)

true_statement_2 = (var_1 == var_4) or (var_1 > var_4) # NOTE: ORIGINAL CODE HAD "STATEMENT" MISPELLED

true_statement_3 = not (var_1 > var_4)

print(true_statement_1)
print(true_statement_2)
print(true_statement_3)
# Out:
# True
# True
# True

# %% [markdown]
# <div class="alert alert-success"><b>Task:</b> For each Boolean operator, create a statement that returns False using any of the comparison operators. </div>

# %%
# Write your code below:

false_statement_1 = (var_1 == var_3) and (var_3 > var_5)

false_statement_2 = (var_1 != var_4) or (var_1 > var_4) # NOTE: ORIGINAL CODE HAD "STATEMENT" MISPELLED

false_statement_3 = not (var_1 == var_4)

print(false_statement_1)
print(false_statement_2)
print(false_statement_3)
# Out:
# False
# False
# False

# %% [markdown]
# ### Operator Chaining
#
# What will the following statements return?

# %% [markdown]
# <div class="alert alert-success"><b>Task:</b> Test combinations of the Boolean operations <code>and</code>, <code>or</code>, & <code>not</code> to see how these variables relate, putting integers, floats, and conditional statements on each side.</div>

# %%
# Make the following statement True
(6 > 10) or (4 == 4) and (11 > 7)
# Out:
# True

# %%
# Make the following statement True
(10 == 10) and (4.0 == 4.00) and (11 > 7)
# Out:
# True

# %%
# Make a False statement
(10 > 10) or (4.0 > 4.00) or (11 < 7)
# Out:
# False

# %% [markdown]
# <a id="conditionals"></a>
#
# ## Conditional Statements
# **Conditionals** are statements that check if a condition is met, using the `if` statement, and then only execute a set of code if the condition evaluates as `True`.
#
# - `if`
# - `elif` (else if): After an `if`, you can use `elif` statements to check additional conditions.
# - `else`: After an `if`, you can use an `else` that will run if the conditional(s) above have not run.
#
# ### If/elif/else syntax
# - Indentation matters! Your statements in the `if` block need to be indented by a tab or four spaces.
# - You need a colon after `if`, `elif`, and `else`

# %%
condition = False

if condition:
    print('This code executes if the condition evaluates as True.')

else:
    print('This code executes if the condition evaluates as False')
# Out:
# This code executes if the condition evaluates as False

# %% [markdown]
# <div class="alert alert-success"><b>Task:</b> Create an if, elif, else statement that updates a variable if a specific condition is met.</div>

# %% [markdown]
# #### Imagine we're recording neural activity from a motion-selective area in the brain:

# %% [markdown]
# from [Henley (2022) *Foundations of Neuroscience: Vision: Central Processing*](https://openbooks.lib.msu.edu/neuroscience/chapter/vision-central-processing/)

# %% [markdown]
# ![AreaMT.png](data:image/png;base64,...)

# %% [markdown]
# *Made in Adobe Illustrator*:

# %% [markdown]
# ![direction_selective_neuron.png](data:image/png;base64,...)

# %% [markdown]
# #### The neuron we are recording from responds strongly to upward motion: 90° in a circular space. This neuron also responds to directions close to 90°, but weaker when compared to a response to 90° motion.

# %%
neuron_spike_count = 0

# We know its preferred motion direction
strongly_preferred_direction = 90
preferred_direction_minimum = strongly_preferred_direction - 10
preferred_direction_maximum = strongly_preferred_direction + 10

# And the current stimulus motion direction -- you can change this!
current_direction = 75

# Simulate neuron spike count
if current_direction == strongly_preferred_direction: # strongly preferred motion direction
    neuron_spike_count = neuron_spike_count + 8

elif (current_direction >= preferred_direction_minimum) and (current_direction <= preferred_direction_maximum): # weakly preferred motion direction
    neuron_spike_count += 3

else:
    print('The neuron is not sensitive to this motion direction!')


print('Neuron spike count: ' + str(neuron_spike_count))
# Out:
# Neuron spike count: 3

# %% [markdown]
# ### Properties of Conditionals
# - Conditionals can take any expression that can be evaluated as `True` or `False`.
# - The order of execution for conditional blocks is *always* `if` then `elif`(s) then `else`.
# - If the `elif` is at the end, it will never be tested, as the `else` will have already returned a value once reached (and Python will throw an error).
# - An `else` statement is not required, but if both the `if` and the `elif` condtions are not met (both evaluate as `False`), then nothing is returned.
# - **At most one component (`if` / `elif` / `else`) of a conditional will run**, which is why the order of your conditional statements is *crucial*.
